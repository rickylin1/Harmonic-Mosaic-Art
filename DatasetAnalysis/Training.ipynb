# %%
# %store -r extended_history
#note must be running in same python env/kernel session

extended_history
# Out:
#                                                song_name      artist_name  \
# 0                                                warning          midwxst
# 1                                                 Lonely  Imagine Dragons
# 2                                   I'll Do It - Sped Up         Six Dior
# 3      Tokyo Drift (Fast & Furious) - From "The Fast ...    Teriyaki Boyz
# 4                       Consume (feat. Goon Des Garcons)   Chase Atlantic
# ...                                                  ...              ...
# 13519                                             Go Boy             ODIE
# 13520                                Any Way You Want Me     BROCKHAMPTON
# 13521                                            BOY BYE     BROCKHAMPTON
# 13522                                             SUMMER     BROCKHAMPTON
# 13523                                            NO HALO     BROCKHAMPTON
#
#                                   album_name  play_count  total_ms_played  \
# ...
