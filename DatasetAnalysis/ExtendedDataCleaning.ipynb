# %%
import pandas as pd

df = pd.read_json("../data/ExtendedStreamingHistory/Streaming_History_Audio_2017-2018_0.json")
df
# Out:
#                          ts     username                     platform  \
# 0      2017-04-26T03:07:46Z  demskillz69  Windows 8.1 (6.3.9600; x64)
# 1      2017-04-26T03:08:19Z  demskillz69  Windows 8.1 (6.3.9600; x64)
# 2      2017-04-26T03:09:11Z  demskillz69  Windows 8.1 (6.3.9600; x64)
# 3      2017-04-26T03:09:39Z  demskillz69  Windows 8.1 (6.3.9600; x64)
# 4      2017-04-26T03:09:49Z  demskillz69  Windows 8.1 (6.3.9600; x64)
# ...                     ...          ...                          ...
# 17031  2018-03-26T04:45:51Z  demskillz69  Windows 8.1 (6.3.9600; x64)
# 17032  2018-03-26T04:45:52Z  demskillz69  Windows 8.1 (6.3.9600; x64)
# 17033  2018-03-26T04:45:53Z  demskillz69  Windows 8.1 (6.3.9600; x64)
# 17034  2018-03-26T04:45:54Z  demskillz69  Windows 8.1 (6.3.9600; x64)
# 17035  2018-03-26T04:45:55Z  demskillz69  Windows 8.1 (6.3.9600; x64)
#
#        ms_played conn_country  ip_addr_decrypted  user_agent_decrypted  \
# ...
